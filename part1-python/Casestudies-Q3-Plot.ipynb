# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
m_values = np.array([40000, 80000, 160000, 320000])
time_m = np.array([0.0604, 0.0731, 0.0756, 0.1435])

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(m_values, time_m, 'o-')
plt.xlabel("m (number of rows)")
plt.ylabel("Time (seconds)")
plt.title("Scaling with m (n = 32)")
plt.grid(True)

plt.subplot(1, 2, 2)
plt.loglog(m_values, time_m, 'o-')
plt.xlabel("m (log scale)")
plt.ylabel("Time (log scale)")
plt.title("Log-Log Scaling with m (n = 32)")
plt.grid(True, which="both")

plt.tight_layout()
plt.show()

# %%
n_values = np.array([16, 32, 64, 128, 256])
time_values = np.array([0.0781, 0.0854, 0.1578, 0.3592, 0.9150])

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(n_values, time_values, 'o-')
plt.xlabel("n (number of columns)")
plt.ylabel("Time (seconds)")
plt.title("Scaling with n (m = 200000)")
plt.grid(True)

plt.subplot(1,2,2)
plt.loglog(n_values, time_values, 'o-')
plt.xlabel("n (log scale)")
plt.ylabel("Time (log scale)")
plt.title("Log-Log Scaling with n (m = 200000)")
plt.grid(True, which="both")

plt.tight_layout()
plt.show()
